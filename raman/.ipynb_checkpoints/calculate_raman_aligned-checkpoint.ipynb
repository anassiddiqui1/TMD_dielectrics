# %%
from utils import *
# %matplotlib inline
import matplotlib.colors as mcolors
import matplotlib.ticker as ticker

# %%
from matplotlib.ticker import MultipleLocator
import numpy as np
import matplotlib.pyplot as plt

# Parameters
x1 = 0
x2 = 0
y = 1
temp = 500
timesteps = 10000
nsteps = 10000
std = 1.5
interval = 1
freq_lim = (1, 1200)
nruns = 50

xspace = np.linspace(0, 1000, 10000)
xspace_static = np.linspace(0, 500, 5000)

# New variables
polarisation = 'unpolarised'  # Change to e.g., 'xx', 'xy' etc. if needed
reduced = True                # Set to False to disable reduced mode

mdict = {0: 'Mo', 1: 'W'}
chdict = {0: 'S', 1: 'Se'}

foldername = 'md_traj_pols/'

# mono1 layer1
freqs, intens_mono1 = calculate_average_spectra(
    foldername, x1, y, temp, timesteps, nsteps,
    nruns, interval, xspace, freq_lim, std,
    derivative=False,
    polarisation=polarisation,
    reduced=reduced
)
intens_mono1 /= max(intens_mono1)

npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x1]}SSe_x{x1:0.3f}y{y:0.3f}_config_0.npz')
freqs_static, intens_static_mono1 = npzfile['freqs'], npzfile['intensities']
freqs_static, intens_static_mono1 = get_spectra_curve(xspace_static, intens_static_mono1, freqs_static, 1)
intens_static_mono1 /= max(intens_static_mono1)

if x2 != x1:
    # monolayer2
    freqs, intens_mono2 = calculate_average_spectra(
        foldername, x2, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std,
        derivative=False,
        polarisation=polarisation,
        reduced=reduced
    )
    intens_mono2 /= max(intens_mono2)

    npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x2]}SSe_x{x2:0.3f}y{y:0.3f}_config_0.npz')
    freqs_static, intens_static_mono2 = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_mono2 = get_spectra_curve(xspace_static, intens_static_mono2, freqs_static, 1)
    intens_static_mono2 /= max(intens_static_mono2)

foldername = 'aligned_layers/bilayer_md_runs/'

print('Works 1')
freqs, intens_2H = calculate_average_spectra(
    foldername, x1, y, temp, timesteps, nsteps,
    nruns, interval, xspace, freq_lim, std,
    x_layer2=[x2, '2H'],
    derivative=False,
    polarisation=polarisation,
    reduced=reduced
)

intens_2H /= max(intens_2H)
print('Works 1')

npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_2H.npz')
freqs_static, intens_static_2H = npzfile['freqs'], npzfile['intensities']
freqs_static, intens_static_2H = get_spectra_curve(xspace_static, intens_static_2H, freqs_static, 1)
intens_static_2H /= max(intens_static_2H)

freqs, intens_3R = calculate_average_spectra(
    foldername, x1, y, temp, timesteps, nsteps,
    nruns, interval, xspace, freq_lim, std,
    x_layer2=[x2, '3R'],
    derivative=False,
    polarisation=polarisation,
    reduced=reduced
)
intens_3R /= max(intens_3R)

npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_3R.npz')
freqs_static, intens_static_3R = npzfile['freqs'], npzfile['intensities']
freqs_static, intens_static_3R = get_spectra_curve(xspace_static, intens_static_3R, freqs_static, 1)
intens_static_3R /= max(intens_static_3R)

# Plotting
fontsize = 20
plt.rcParams['font.size'] = fontsize
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

colors = {
    'mono1': '#1f77b4',
    'mono2': '#9467bd',
    '2H': '#2ca02c',
    '3R': '#d62728'
}

for i, (freq_low, freq_high) in enumerate([(0, 60), (280, 380)]):
    text_offset = 0.0003 if i == 0 else 0.1

    condition_full = (freq_low < freqs) & (freqs < freq_high)
    freqs_plot = freqs[condition_full]
    condition_static = (freq_low < freqs_static) & (freqs_static < freq_high)
    freqs_static_plot = freqs_static[condition_static]

    # mono1
    intens_mono1_plot = intens_mono1[condition_full]
    axs[i].plot(freqs_plot, intens_mono1_plot, color=colors['mono1'])
    axs[i].text(freq_low + 1, min(intens_mono1_plot) + text_offset, 'mono1', va='bottom')

    intens_static_mono1_plot = intens_static_mono1[condition_static] + min(intens_mono1_plot)
    axs[i].plot(freqs_static_plot, intens_static_mono1_plot, color=colors['mono1'], linestyle='--')

    offset = 5 * max(intens_mono1_plot) if freq_low == 0 else 0.4 * max(intens_mono1_plot)

    if x2 != x1:
        intens_mono2_plot = intens_mono2[condition_full] + max(intens_mono1_plot) + offset
        axs[i].plot(freqs_plot, intens_mono2_plot, color=colors['mono2'])
        axs[i].text(freq_low + 1, min(intens_mono2_plot) + text_offset, 'mono2', va='bottom')

        intens_static_mono2_plot = intens_static_mono2[condition_static] + min(intens_mono2_plot)
        axs[i].plot(freqs_static_plot, intens_static_mono2_plot, color=colors['mono2'], linestyle='--')
    else:
        intens_mono2_plot = intens_mono1_plot

    # 2H
    intens_2H_plot = intens_2H[condition_full] + max(intens_mono2_plot) + offset
    axs[i].plot(freqs_plot, intens_2H_plot, color=colors['2H'])
    axs[i].text(freq_low + 1, min(intens_2H_plot) + text_offset, '2H', va='bottom')

    intens_static_2H_plot = intens_static_2H[condition_static] + min(intens_2H_plot)
    axs[i].plot(freqs_static_plot, intens_static_2H_plot, color=colors['2H'], linestyle='--')

    # 3R
    intens_3R_plot = intens_3R[condition_full] + max(intens_2H_plot) + offset
    axs[i].plot(freqs_plot, intens_3R_plot, color=colors['3R'])
    axs[i].text(freq_low + 1, min(intens_3R_plot) + text_offset, '3R', va='bottom')

    intens_static_3R_plot = intens_static_3R[condition_static] + min(intens_3R_plot)
    axs[i].plot(freqs_static_plot, intens_static_3R_plot, color=colors['3R'], linestyle='--')

    axs[i].xaxis.set_minor_locator(MultipleLocator(5))
    axs[i].set_xlim(freq_low, freq_high)
    axs[i].set_yticks([])
    axs[i].text(0.01, 0.98, f"({chr(ord('a') + i)})", va='top',
                transform=axs[i].transAxes, fontsize=fontsize + 2, fontweight='bold')

plt.subplots_adjust(wspace=0.15)
fig.text(0.5, -0.01, r'Raman shift (cm$^{-1}$)', ha='center', fontsize=fontsize + 2)
fig.text(0.08, 0.5, 'Intensity (a.u.)', va='center', rotation='vertical', fontsize=fontsize + 2)

# plt.savefig('aligned_raman_mos2', facecolor='white', transparent=False, dpi=300,
#             bbox_inches='tight', pad_inches=0.02)

plt.show()
# Out:
# 15 trajectories used..
# Works 1
# 50 trajectories used..
# Works 1
# 50 trajectories used..

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import MultipleLocator

# --- PARAMETERS ---
x1 = 0
x2 = 0
y = 1
temp = 500
timesteps = 10000
nsteps = 10000
std = 2
interval = 1
freq_lim = (10,1200)
nruns = 50
xspace = np.linspace(0, 1000, 10000)
xspace_static = np.linspace(0, 500, 5000)

mdict = {0: 'Mo', 1: 'W'}
chdict = {0: 'S', 1: 'Se'}

polarisation = 'unpolarised'
reduced = True

# --- MONOLAYER 1 ---
foldername = 'md_traj_pols/'
freqs, intens_mono1 = calculate_average_spectra(
    foldername, x1, y, temp, timesteps, nsteps,
    nruns, interval, xspace, freq_lim, std, derivative=False,
    polarisation=polarisation,
    reduced = reduced
)
intens_mono1 /= max(intens_mono1)

npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x1]}SSe_x{x1:0.3f}y{y:0.3f}_config_0.npz')
freqs_static, intens_static_mono1 = npzfile['freqs'], npzfile['intensities']
freqs_static, intens_static_mono1 = get_spectra_curve(xspace_static, intens_static_mono1, freqs_static, 1)
intens_static_mono1 /= max(intens_static_mono1)

# --- MONOLAYER 2 (if different) ---
if x2 != x1:
    freqs, intens_mono2 = calculate_average_spectra(
        foldername, x2, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std, derivative=False,
        polarisation='unpolarised'
    )
    intens_mono2 /= max(intens_mono2)

    npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x2]}SSe_x{x2:0.3f}y{y:0.3f}_config_0.npz')
    freqs_static, intens_static_mono2 = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_mono2 = get_spectra_curve(xspace_static, intens_static_mono2, freqs_static, 1)
    intens_static_mono2 /= max(intens_static_mono2)

# --- BILAYER: 2H ---
foldername = 'aligned_layers/bilayer_md_runs/'
freqs, intens_2H = calculate_average_spectra(
    foldername, x1, y, temp, timesteps, nsteps,
    nruns, interval, xspace, freq_lim, std,
    x_layer2=[x2, '2H'], derivative=False,
    polarisation=polarisation,
    reduced=True
)
intens_2H /= max(intens_2H)
npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_2H.npz')
freqs_static, intens_static_2H = npzfile['freqs'], npzfile['intensities']
freqs_static, intens_static_2H = get_spectra_curve(xspace_static, intens_static_2H, freqs_static, 1)
intens_static_2H /= max(intens_static_2H)

# --- BILAYER: 3R ---
freqs, intens_3R = calculate_average_spectra(
    foldername, x1, y, temp, timesteps, nsteps,
    nruns, interval, xspace, freq_lim, std,
    x_layer2=[x2, '3R'], derivative=False,
    polarisation=polarisation,
    reduced=True
)
intens_3R /= max(intens_3R)
npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_3R.npz')
freqs_static, intens_static_3R = npzfile['freqs'], npzfile['intensities']
freqs_static, intens_static_3R = get_spectra_curve(xspace_static, intens_static_3R, freqs_static, 1)
intens_static_3R /= max(intens_static_3R)
# --- PLOTTING ---
fontsize = 20
plt.rcParams['font.size'] = fontsize
fig = plt.figure(figsize=(7, 6))
gs = GridSpec(1, 2, width_ratios=[0.7, 1], wspace=0.05)
ax_left = fig.add_subplot(gs[0])
ax_right = fig.add_subplot(gs[1])  # Different y-scale allowed
axs = [ax_left, ax_right]
ax_left.spines['right'].set_visible(False)
ax_right.spines['left'].set_visible(False)


colors = {
    'mono1': '#1f77b4',
    'mono2': '#9467bd',
    '2H': '#2ca02c',
    '3R': '#d62728'
}

for i, (freq_low, freq_high) in enumerate([(0, 60), (280, 450)]):
    ax = axs[i]
    text_offset = 0.002 if i == 0 else 0.1

    condition_full = (freq_low < freqs) & (freqs < freq_high)
    freqs_plot = freqs[condition_full]
    condition_static = (freq_low < freqs_static) & (freqs_static < freq_high)
    freqs_static_plot = freqs_static[condition_static]

    intens_mono1_plot = intens_mono1[condition_full]
    ax.plot(freqs_plot, intens_mono1_plot, color=colors['mono1'])
    if i == 0:
        ax.text(freq_low + 1, min(intens_mono1_plot) + text_offset, rf'1L-{mdict[x1]}{chdict[y]}$_{2}$', va='bottom')

    intens_static_mono1_plot = intens_static_mono1[condition_static] + min(intens_mono1_plot)
    ax.plot(freqs_static_plot, intens_static_mono1_plot, color=colors['mono1'], linestyle='--')

    offset = 10 * max(intens_mono1_plot) if freq_low == 0 else 0.05 * max(intens_mono1_plot)

    if x2 != x1:
        intens_mono2_plot = intens_mono2[condition_full] + max(intens_mono1_plot) + offset
        ax.plot(freqs_plot, intens_mono2_plot, color=colors['mono2'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_mono2_plot) + text_offset, rf'1L-{mdict[x2]}{chdict[y]}$_{2}$', va='bottom')

        intens_static_mono2_plot = intens_static_mono2[condition_static] + min(intens_mono2_plot)
        ax.plot(freqs_static_plot, intens_static_mono2_plot, color=colors['mono2'], linestyle='--')
    else:
        intens_mono2_plot = intens_mono1_plot

    intens_2H_plot = intens_2H[condition_full] + max(intens_mono2_plot) + offset
    ax.plot(freqs_plot, intens_2H_plot, color=colors['2H'])
    if i == 0:
        ax.text(freq_low + 1, min(intens_2H_plot) + text_offset, '2L-2H', va='bottom')

    intens_static_2H_plot = intens_static_2H[condition_static] + min(intens_2H_plot)
    ax.plot(freqs_static_plot, intens_static_2H_plot, color=colors['2H'], linestyle='--')

    intens_3R_plot = intens_3R[condition_full] + max(intens_2H_plot) + offset
    ax.plot(freqs_plot, intens_3R_plot, color=colors['3R'])
    if i == 0:
        ax.text(freq_low + 1, min(intens_3R_plot) + text_offset, '2L-3R', va='bottom')

    intens_static_3R_plot = intens_static_3R[condition_static] + min(intens_3R_plot)
    ax.plot(freqs_static_plot, intens_static_3R_plot, color=colors['3R'], linestyle='--')

    ax.xaxis.set_minor_locator(MultipleLocator(5))
    ax.set_xlim(freq_low, freq_high)
    ax.set_yticks([])
    
ax_left.text(0.01, 0.99,
             rf"({chr(ord('a'))}) {mdict[x1]}{chdict[y]}$_{2}$/{mdict[x2]}{chdict[y]}$_{2}$",
             va='top', transform=ax_left.transAxes,fontsize=fontsize)

# Diagonal break marks
d = .005
kwargs = dict(transform=ax_left.transAxes, color='k', clip_on=False)
ax_left.plot((1 - d, 1 + d), (-d, +d), **kwargs)
ax_left.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

kwargs.update(transform=ax_right.transAxes)
ax_right.plot((-d, +d), (-d, +d), **kwargs)
ax_right.plot((-d, +d), (1 - d, 1 + d), **kwargs)

ax_right.tick_params(labelleft=False)

# Shared axis labels
fig.text(0.5, -0.01, r'Raman shift (cm$^{-1}$)', ha='center', fontsize=fontsize + 2)
fig.text(0.08, 0.5, 'Intensity (a.u.)', va='center', rotation='vertical', fontsize=fontsize + 2)

plt.show()
# Out:
# 15 trajectories used..
# 50 trajectories used..
# 50 trajectories used..

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec,GridSpecFromSubplotSpec
from matplotlib.ticker import MultipleLocator

def plot_raman_aligned(axs, x1, x2, y,low_range,high_range, index):
    
    # --- PARAMETERS ---
    temp = 300
    timesteps = 10000
    nsteps = 10000
    std = 1.5
    interval = 1
    freq_lim = (0,1000)
    nruns = 50
    xspace = np.linspace(0,1000,10000)
    xspace_static = np.linspace(0, 500, 5000)
    polarisation = 'unpolarised'


    mdict = {0: 'Mo', 1: 'W'}
    chdict = {0: 'S', 1: 'Se'}

    # --- MONOLAYER 1 ---
    foldername = 'md_traj_pols/'
    freqs, intens_mono1 = calculate_average_spectra(
        foldername, x1, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std, derivative=False,
        polarisation=polarisation,reduced=True
    )
    intens_mono1 /= max(intens_mono1)

    npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x1]}SSe_x{x1:0.3f}y{y:0.3f}_config_0.npz')
    freqs_static, intens_static_mono1 = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_mono1 = get_spectra_curve(xspace_static, intens_static_mono1, freqs_static, 1)
    intens_static_mono1 /= max(intens_static_mono1)

    # --- MONOLAYER 2 ---
    if x2 != x1:
        freqs, intens_mono2 = calculate_average_spectra(
            foldername, x2, y, temp, timesteps, nsteps,
            nruns, interval, xspace, freq_lim, std, derivative=False,
            polarisation=polarisation,reduced=True
        )
        intens_mono2 /= max(intens_mono2)

        npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x2]}SSe_x{x2:0.3f}y{y:0.3f}_config_0.npz')
        freqs_static, intens_static_mono2 = npzfile['freqs'], npzfile['intensities']
        freqs_static, intens_static_mono2 = get_spectra_curve(xspace_static, intens_static_mono2, freqs_static, 1)
        intens_static_mono2 /= max(intens_static_mono2)

    # --- BILAYER 2H ---
    foldername = 'aligned_layers/bilayer_md_runs/'
    freqs, intens_2H = calculate_average_spectra(
        foldername, x1, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std,
        x_layer2=[x2, '2H'], derivative=False,
        polarisation=polarisation,reduced=True
    )
    intens_2H /= max(intens_2H)
    npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_2H.npz')
    freqs_static, intens_static_2H = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_2H = get_spectra_curve(xspace_static, intens_static_2H, freqs_static, 1)
    intens_static_2H /= max(intens_static_2H)

    # --- BILAYER 3R ---
    freqs, intens_3R = calculate_average_spectra(
        foldername, x1, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std,
        x_layer2=[x2, '3R'], derivative=False,
        polarisation=polarisation,reduced=True
    )
    intens_3R /= max(intens_3R)
    npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_3R.npz')
    freqs_static, intens_static_3R = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_3R = get_spectra_curve(xspace_static, intens_static_3R, freqs_static, 1)
    intens_static_3R /= max(intens_static_3R)

    ax_left, ax_right = axs
    ax_left.spines['right'].set_visible(False)
    ax_right.spines['left'].set_visible(False)

    colors = {'mono1': '#1f77b4', 'mono2': '#9467bd', '2H': '#2ca02c', '3R': '#d62728'}

    for i, xrange in enumerate([low_range,high_range]):
        
        freq_low,freq_high = xrange
        ax = axs[i]
        #text_offset = 0.002 if i == 0 else 0.1

        condition_full = (freq_low < freqs) & (freqs < freq_high)
        freqs_plot = freqs[condition_full]
        freqs_plot*=1.045
        
        condition_static = (freq_low < freqs_static) & (freqs_static < freq_high)
        freqs_static_plot = freqs_static[condition_static]
        freqs_static_plot*=1.035
        
        intens_mono1_plot = intens_mono1[condition_full]
        ax.plot(freqs_plot, intens_mono1_plot, color=colors['mono1'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_mono1_plot) + 1.1*(max(intens_mono1_plot)-min(intens_mono1_plot)),
                    rf'1L-{mdict[x1]}{chdict[y]}$_2$', va='bottom',fontsize = fontsize-3)

        intens_static_mono1_plot = intens_static_mono1[condition_static] + min(intens_mono1_plot)
        ax.plot(freqs_static_plot, intens_static_mono1_plot, color=colors['mono1'], linestyle='--')

        offset = 2 * max(intens_mono1_plot) if freq_low == 0 else 0.05 * max(intens_mono1_plot)

        if x2 != x1:
            intens_mono2_plot = intens_mono2[condition_full] + max(intens_mono1_plot) + offset
            ax.plot(freqs_plot, intens_mono2_plot, color=colors['mono2'])
            if i == 0:
                ax.text(freq_low + 1, min(intens_mono2_plot) + 1.1*(max(intens_mono2_plot)-min(intens_mono2_plot)),
                        rf'1L-{mdict[x2]}{chdict[y]}$_2$', va='bottom',fontsize = fontsize-3)

            intens_static_mono2_plot = intens_static_mono2[condition_static] + min(intens_mono2_plot)
            ax.plot(freqs_static_plot, intens_static_mono2_plot, color=colors['mono2'], linestyle='--')
        else:
            intens_mono2_plot = intens_mono1_plot

        intens_2H_plot = intens_2H[condition_full] + max(intens_mono2_plot) + offset
        ax.plot(freqs_plot, intens_2H_plot, color=colors['2H'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_2H_plot) + 1.1*(max(intens_2H_plot)-min(intens_2H_plot)),
                    '2L-2H', va='bottom',fontsize = fontsize-3)

        intens_static_2H_plot = intens_static_2H[condition_static] + min(intens_2H_plot)
        ax.plot(freqs_static_plot, intens_static_2H_plot, color=colors['2H'], linestyle='--')

        intens_3R_plot = intens_3R[condition_full] + max(intens_2H_plot) + offset
        ax.plot(freqs_plot, intens_3R_plot, color=colors['3R'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_3R_plot) + 1.1*(max(intens_3R_plot)-min(intens_3R_plot)), 
                    '2L-3R', va='bottom',fontsize = fontsize-3)

        intens_static_3R_plot = intens_static_3R[condition_static] + min(intens_3R_plot)
        ax.plot(freqs_static_plot, intens_static_3R_plot, color=colors['3R'], linestyle='--')

        ax_left.xaxis.set_minor_locator(MultipleLocator(5))
        ax_right.xaxis.set_minor_locator(MultipleLocator(50))
        ax.set_xlim(freq_low, freq_high)
        ax.set_yticks([])
    
        if i== 0:
            if y == 0:
                ax.set_ylim(top = max(intens_static_3R_plot) + 0.6*(max(intens_static_3R_plot)-min(intens_static_3R_plot)))
            else:
                ax.set_ylim(top = max(intens_static_3R_plot) + 1.2*(max(intens_static_3R_plot)-min(intens_static_3R_plot)))
#     ax_left.text(0.01, 0.99,
#                  rf"({chr(ord('a') + index)}) {mdict[x1]}{chdict[y]}$\bf _2$/{mdict[x2]}{chdict[y]}$\bf _2$",
#                  va='top', transform=ax_left.transAxes,fontweight='bold')

    
    ax_right.xaxis.set_major_locator(MultipleLocator(100))
    ax_left.text(0.01,0.99,rf"({chr(ord('a') + index)}) ",
                 transform=ax_left.transAxes,va='top',fontweight='bold')
    label = rf"{mdict[x1]}{chdict[y]}$\bf _2$/"+"\n"+rf"{mdict[x2]}{chdict[y]}$\bf _2$"
    ax_left.text(0.3, 0.99,label,
                 va='top',transform=ax_left.transAxes,fontweight='bold')

    # Diagonal breaks
    d = .01
    kwargs = dict(transform=ax_left.transAxes, color='k', clip_on=False)
    ax_left.plot((1 - d, 1 + d), (-d, +d), **kwargs)
    ax_left.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

    kwargs.update(transform=ax_right.transAxes)
    ax_right.plot((-d, +d), (-d, +d), **kwargs)
    ax_right.plot((-d, +d), (1 - d, 1 + d), **kwargs)
    ax_right.tick_params(labelleft=False)

# --- MAIN FIGURE ---
fontsize = 20
plt.rcParams['font.size'] = fontsize
fig = plt.figure(figsize=(14, 18))
outer_gs = GridSpec(3, 2, figure=fig, wspace=0.1, hspace=0.15)

combinations = [(x1, x2, y) for x1, x2 in [(0, 0), (1, 1), (0, 1)] for y in [0, 1]]


for idx, (x1, x2, y) in enumerate(combinations):
    row, col = divmod(idx, 2)
    gs = GridSpecFromSubplotSpec(1, 2, width_ratios=[0.7, 1], wspace=0.05, subplot_spec=outer_gs[row, col])
    ax_left = fig.add_subplot(gs[0])
    ax_right = fig.add_subplot(gs[1])
    low_range = (0,60)
    high_range = (300,450) if y==0 else (150,400)
    plot_raman_aligned([ax_left, ax_right], x1, x2, y,low_range,high_range, idx)


fig.text(0.5, 0.08, r'Raman shift (cm$^{-1}$)', ha='center', fontsize=fontsize+2)
fig.text(0.09, 0.5, 'Intensity (a.u.)', va='center', rotation='vertical', fontsize=fontsize+2)
# fig.tight_layout()
plt.savefig('aligned_raman_combined.png',facecolor='white', transparent=False, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 189
#     187     low_range = (0,60)
#     188     high_range = (300,450) if y==0 else (150,400)
# --> 189     plot_raman_aligned([ax_left, ax_right], x1, x2, y,low_range,high_range, idx)
#     192 fig.text(0.5, 0.08, r'Raman shift (cm$^{-1}$)', ha='center', fontsize=fontsize+2)
#     193 fig.text(0.09, 0.5, 'Intensity (a.u.)', va='center', rotation='vertical', fontsize=fontsize+2)
#
# Cell In [2], line 26, in plot_raman_aligned(axs, x1, x2, y, low_range, high_range, index)
#      24 # --- MONOLAYER 1 ---
#      25 foldername = 'md_traj_pols/'
# ---> 26 freqs, intens_mono1 = calculate_average_spectra(
#      27     foldername, x1, y, temp, timesteps, nsteps,
#      28     nruns, interval, xspace, freq_lim, std, derivative=False,
#      29     polarisation=polarisation,reduced=True
#      30 )
#      31 intens_mono1 /= max(intens_mono1)
#      33 npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x1]}SSe_x{x1:0.3f}y{y:0.3f}_config_0.npz')
#
# File ~/Research_Data/dielectrics/utils.py:226, in calculate_average_spectra(foldername, x, y, temp, timesteps, nsteps, nruns, interval, xspace, freq_lim, std, x_layer2, derivative, polarisation, reduced)
#     223     continue
#     225 total_runs += 1
# --> 226 data = np.load(npzfile)
#     227 times = data['times'][:nsteps:interval]
#     228 suscs = data['suscs'][:nsteps:interval]
#
# File /software/easybuild/software/PyTorch/2.0-Miniconda3-4.12.0-Python-3.10.8/lib/python3.10/site-packages/numpy/lib/npyio.py:434, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     432 _ZIP_SUFFIX = b'PK\x05\x06' # empty zip files start with this
#     433 N = len(format.MAGIC_PREFIX)
# --> 434 magic = fid.read(N)
#     435 if not magic:
#     436     raise EOFError("No data left in file")
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec,GridSpecFromSubplotSpec
from matplotlib.ticker import MultipleLocator

def plot_raman_aligned(axs, x1, x2, y,low_range,high_range, index):
    
    # --- PARAMETERS ---
    temp = 300
    timesteps = 10000
    nsteps = 10000
    std = 3
    interval = 1
    freq_lim = (0,1000)
    nruns = 50
    xspace = np.linspace(0,1000,10000)
    xspace_static = np.linspace(0, 500, 5000)
    polarisation = 'unpolarised'


    mdict = {0: 'Mo', 1: 'W'}
    chdict = {0: 'S', 1: 'Se'}
    
    label = rf"({chr(ord('a') + index)}) {mdict[x1]}{chdict[y]}$_2$/{mdict[x2]}{chdict[y]}$_2$" 
    print(rf'Running calculations for {label}')

    # --- MONOLAYER 1 ---
    foldername = 'md_traj_pols/'
    freqs, intens_mono1 = calculate_average_spectra(
        foldername, x1, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std, derivative=False,
        polarisation=polarisation,reduced=True
    )
    intens_mono1 /= max(intens_mono1)

    npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x1]}SSe_x{x1:0.3f}y{y:0.3f}_config_0.npz')
    freqs_static, intens_static_mono1 = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_mono1 = get_spectra_curve(xspace_static, intens_static_mono1, freqs_static, std)
    intens_static_mono1 /= max(intens_static_mono1)

    # --- MONOLAYER 2 ---
    if x2 != x1:
        freqs, intens_mono2 = calculate_average_spectra(
            foldername, x2, y, temp, timesteps, nsteps,
            nruns, interval, xspace, freq_lim, std, derivative=False,
            polarisation=polarisation,reduced=True
        )
        intens_mono2 /= max(intens_mono2)

        npzfile = np.load(f'raman_data_dielectrics_w10_1/{mdict[x2]}SSe_x{x2:0.3f}y{y:0.3f}_config_0.npz')
        freqs_static, intens_static_mono2 = npzfile['freqs'], npzfile['intensities']
        freqs_static, intens_static_mono2 = get_spectra_curve(xspace_static, intens_static_mono2, freqs_static, std)
        intens_static_mono2 /= max(intens_static_mono2)

    # --- BILAYER 2H ---
    foldername = 'aligned_layers/bilayer_md_runs/'
    freqs, intens_2H = calculate_average_spectra(
        foldername, x1, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std,
        x_layer2=[x2, '2H'], derivative=False,
        polarisation=polarisation,reduced=True
    )
    intens_2H /= max(intens_2H)
    npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_2H.npz')
    freqs_static, intens_static_2H = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_2H = get_spectra_curve(xspace_static, intens_static_2H, freqs_static, std)
    intens_static_2H /= max(intens_static_2H)

    # --- BILAYER 3R ---
    freqs, intens_3R = calculate_average_spectra(
        foldername, x1, y, temp, timesteps, nsteps,
        nruns, interval, xspace, freq_lim, std,
        x_layer2=[x2, '3R'], derivative=False,
        polarisation=polarisation,reduced=True
    )
    intens_3R /= max(intens_3R)
    npzfile = np.load(f'raman_data_aligned/{mdict[x1]}{mdict[x2]}{chdict[y]}_3R.npz')
    freqs_static, intens_static_3R = npzfile['freqs'], npzfile['intensities']
    freqs_static, intens_static_3R = get_spectra_curve(xspace_static, intens_static_3R, freqs_static, std)
    intens_static_3R /= max(intens_static_3R)

    ax_left, ax_right = axs
    ax_left.spines['right'].set_visible(False)
    ax_right.spines['left'].set_visible(False)

    colors = {'mono1': '#1f77b4', 'mono2': '#9467bd', '2H': '#2ca02c', '3R': '#d62728'}

    for i, xrange in enumerate([low_range,high_range]):
        
        freq_low,freq_high = xrange
        ax = axs[i]
        #text_offset = 0.002 if i == 0 else 0.1

        condition_full = (freq_low < freqs) & (freqs < freq_high)
        freqs_plot = freqs[condition_full]
        freqs_plot*=1.045
        
        condition_static = (freq_low < freqs_static) & (freqs_static < freq_high)
        freqs_static_plot = freqs_static[condition_static]
        freqs_static_plot*=1.035
        
        intens_mono1_plot = intens_mono1[condition_full]
        ax.plot(freqs_plot, intens_mono1_plot, color=colors['mono1'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_mono1_plot) + 1.1*(max(intens_mono1_plot)-min(intens_mono1_plot)),
                    rf'1L-{mdict[x1]}{chdict[y]}$_2$', va='bottom',fontsize = fontsize-2)

        intens_static_mono1_plot = intens_static_mono1[condition_static] + min(intens_mono1_plot)
        ax.plot(freqs_static_plot, intens_static_mono1_plot, color=colors['mono1'], linestyle='--')

        offset = 2 * max(intens_mono1_plot) if freq_low == 0 else 0.05 * max(intens_mono1_plot)

        if x2 != x1:
            intens_mono2_plot = intens_mono2[condition_full] + max(intens_mono1_plot) + offset
            ax.plot(freqs_plot, intens_mono2_plot, color=colors['mono2'])
            if i == 0:
                ax.text(freq_low + 1, min(intens_mono2_plot) + 1.1*(max(intens_mono2_plot)-min(intens_mono2_plot)),
                        rf'1L-{mdict[x2]}{chdict[y]}$_2$', va='bottom',fontsize = fontsize-2)

            intens_static_mono2_plot = intens_static_mono2[condition_static] + min(intens_mono2_plot)
            ax.plot(freqs_static_plot, intens_static_mono2_plot, color=colors['mono2'], linestyle='--')
        else:
            intens_mono2_plot = intens_mono1_plot

        # 2H full spectra
        intens_2H_plot = intens_2H[condition_full] + max(intens_mono2_plot) + offset
        ax.plot(freqs_plot, intens_2H_plot, color=colors['2H'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_2H_plot) + 1.1*(max(intens_2H_plot)-min(intens_2H_plot)),
                    '2L-2H', va='bottom',fontsize = fontsize-2)
            
#             shear_x,shear_y = get_max_peak(freqs_plot,intens_2H_plot,0,23)
    
#             breathing_x,breathing_y = get_max_peak(freqs_plot,intens_2H_plot,23,42)
            
#             print(f'2H : Shear Mode frequency = {shear_x} ; Breathing Mode frequency = {breathing_x}')

        intens_static_2H_plot = intens_static_2H[condition_static] + min(intens_2H_plot)
        ax.plot(freqs_static_plot, intens_static_2H_plot, color=colors['2H'], linestyle='--')

        #3R full spectra
        intens_3R_plot = intens_3R[condition_full] + max(intens_2H_plot) + offset
        ax.plot(freqs_plot, intens_3R_plot, color=colors['3R'])
        if i == 0:
            ax.text(freq_low + 1, min(intens_3R_plot) + 1.1*(max(intens_3R_plot)-min(intens_3R_plot)), 
                    '2L-3R', va='bottom',fontsize = fontsize-2)
            
#             if x1==1 and x2==1 and y==1:
#                 shear_x,shear_y = get_max_peak(freqs_plot,intens_3R_plot,0,20)
#                 breathing_x,breathing_y = get_max_peak(freqs_plot,intens_3R_plot,20,30)
                
#             else:
#                 shear_x,shear_y = get_max_peak(freqs_plot,intens_3R_plot,0,25)
#                 breathing_x,breathing_y = get_max_peak(freqs_plot,intens_3R_plot,25,50)
            
#             print(f'3R : Shear Mode frequency = {shear_x} ; Breathing Mode frequency = {breathing_x}')

        intens_static_3R_plot = intens_static_3R[condition_static] + min(intens_3R_plot)
        ax.plot(freqs_static_plot, intens_static_3R_plot, color=colors['3R'], linestyle='--')

        ax_left.xaxis.set_minor_locator(MultipleLocator(5))
        ax_right.xaxis.set_minor_locator(MultipleLocator(10))
        ax.set_xlim(freq_low, freq_high)
        ax.set_yticks([])
    
        if i== 0:
            if y == 0:
                ax.set_ylim(top = max(intens_static_3R_plot) + 0.6*(max(intens_static_3R_plot)-min(intens_static_3R_plot)))
            else:
                ax.set_ylim(top = max(intens_static_3R_plot) + 1.2*(max(intens_static_3R_plot)-min(intens_static_3R_plot)))

    
       
    ax.text(0.03, 0.97,label,
                 va='top',transform=ax_left.transAxes,clip_on=False)
    
    mag_factor = (ax_right.get_ylim()[1]-ax_right.get_ylim()[0])/(ax_left.get_ylim()[1]-ax_left.get_ylim()[0])
    
    ax_left.text(1, 0.87, f'×{mag_factor:.2f}', transform=ax_left.transAxes,
                    ha='right', va='top', fontsize=fontsize-2, color='gray', alpha=0.7)

    # Diagonal breaks
    d = .01
    kwargs = dict(transform=ax_left.transAxes, color='k', clip_on=False)
    ax_left.plot((1 - d, 1 + d), (-d, +d), **kwargs)
    ax_left.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

    kwargs.update(transform=ax_right.transAxes)
    ax_right.plot((-d, +d), (-d, +d), **kwargs)
    ax_right.plot((-d, +d), (1 - d, 1 + d), **kwargs)
    ax_right.tick_params(labelleft=False)

# --- MAIN FIGURE ---
fontsize = 9.5
plt.rcParams['font.size'] = fontsize
plt.rcParams['lines.linewidth'] = 1
fig = plt.figure(figsize=(9, 4.5))
outer_gs = GridSpec(2, 3, figure=fig, wspace=0.1, hspace=0.15)

combinations = [(x1, x2, y) for y in [0, 1] for x1, x2 in [(0, 0), (1, 1), (0, 1)] ]


for idx, (x1, x2, y) in enumerate(combinations):
    row, col = divmod(idx, 3)
    gs = GridSpecFromSubplotSpec(1, 2, width_ratios=[0.7, 1], wspace=0.05, subplot_spec=outer_gs[row, col])
    ax_left = fig.add_subplot(gs[0])
    ax_right = fig.add_subplot(gs[1])
    low_range = (0,60)
    high_range = (310,450) if y==0 else (150,400)
    plot_raman_aligned([ax_left, ax_right], x1, x2, y,low_range,high_range, idx)


fig.text(0.5, 0.045, r'Raman shift (cm$^{-1}$)', ha='center', fontsize=fontsize+2)
fig.text(0.1, 0.5, 'Intensity (a.u.)', va='center', rotation='vertical', fontsize=fontsize+2)
# fig.tight_layout()
plt.savefig('aligned_raman_combined_transposed.png',facecolor='white', transparent=False, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Running calculations for (a) MoS$_2$/MoS$_2$
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
# Running calculations for (b) WS$_2$/WS$_2$
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
# Running calculations for (c) MoS$_2$/WS$_2$
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
# Running calculations for (d) MoSe$_2$/MoSe$_2$
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
# Running calculations for (e) WSe$_2$/WSe$_2$
# 50 trajectories used..
# 50 trajectories used..
# 49 trajectories used..
# Running calculations for (f) MoSe$_2$/WSe$_2$
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
# 50 trajectories used..
